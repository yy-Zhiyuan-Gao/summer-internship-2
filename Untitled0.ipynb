# %% [markdown]
# <a href="https://colab.research.google.com/github/yy-Zhiyuan-Gao/summer-internship-2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow pillow

from PIL import Image
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# 加载模型
model = tf.keras.applications.MobileNetV2(weights='imagenet')

# 上传图像
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
    # 读取图片
    image = Image.open(fn).convert("RGB")
    image = image.resize((224, 224))
    x = tf.keras.preprocessing.image.img_to_array(image)
    x = np.expand_dims(x, axis=0)
    x = tf.keras.applications.mobilenet_v2.preprocess_input(x)

    # 预测
    preds = model.predict(x)
    decoded = tf.keras.applications.mobilenet_v2.decode_predictions(preds, top=1)[0][0]
    label = decoded[1]
    prob = decoded[2]

    # 显示结果
    print(f"预测结果：{label}，置信度：{prob:.2f}")
    display(image)
# Out:
# ...
# 14536120/14536120 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#      <input type="file" id="files-6b471f75-a2d7-4630-909b-66e6c86ccec6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b471f75-a2d7-4630-909b-66e6c86ccec6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
